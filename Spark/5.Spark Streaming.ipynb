# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from pyspark.sql.functions import split

spark = SparkSession \
    .builder \
    .appName("StructuredNetworkWordCount") \
    .getOrCreate()
# Out:
# 26/05/13 17:16:10 WARN SparkSession: Using an existing Spark session; only runtime SQL configurations will take effect.

# %%
# creating Dataframe representing the stream of input lines from connection to localhost:9999

lines = spark \
    .readStream \
    .format("socket") \
    .option("host", "localhost") \
    .option("port", 9999) \
    .load()

#split lines into words
words = lines.select(
    explode(
        split(lines.value, " ")
    ).alias("word")
)

# Generate running word count
wordCounts = words.groupBy("word").count()
# Out:
# 26/05/13 17:21:10 WARN TextSocketSourceProvider: The socket source should not be used for production applications! It does not support recovery.

# %%
 # Start running the query that prints the running counts to the console

query = wordCounts \
    .writeStream \
    .outputMode("complete") \
    .format("console") \
    .start()

query.awaitTermination()
# Out:
# 26/05/13 17:29:54 WARN ResolveWriteToStream: Temporary checkpoint location created which is deleted normally when the query didn't fail: /tmp/temporary-1adfabda-bc54-4501-a237-07325342dec1. If it's required to delete it under any circumstances, please set spark.sql.streaming.forceDeleteTempCheckpointLocation to true. Important to know deleting temp checkpoint folder is best effort.
# 26/05/13 17:29:54 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# -------------------------------------------
# Batch: 0
# -------------------------------------------
# +----+-----+
# |word|count|
# +----+-----+
# +----+-----+
# -------------------------------------------
# Batch: 1
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    1|
# +------+-----+
# -------------------------------------------
# Batch: 2
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    1|
# | spark|    1|
# +------+-----+
# -------------------------------------------
# Batch: 3
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    2|
# | spark|    1|
# +------+-----+
# -------------------------------------------
# Batch: 4
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    2|
# | spark|    1|
# |hadoop|    1|
# +------+-----+
# -------------------------------------------
# Batch: 5
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    2|
# | spark|    1|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 6
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    2|
# | spark|    1|
# | flume|    1|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 7
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    2|
# | spark|    1|
# | flume|    1|
# | sqoop|    1|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 8
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# |apache|    2|
# | spark|    1|
# | flume|    1|
# | sqoop|    2|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 9
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# | kafka|    1|
# |apache|    2|
# | spark|    1|
# | flume|    1|
# | sqoop|    2|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 10
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# | kafka|    1|
# |apache|    2|
# | spark|    2|
# | flume|    1|
# | sqoop|    2|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 11
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# | kafka|    1|
# |apache|    2|
# | spark|    2|
# | flume|    1|
# | sqoop|    3|
# |hadoop|    1|
# |  hive|    1|
# +------+-----+
# -------------------------------------------
# Batch: 12
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# | kafka|    1|
# |apache|    2|
# | spark|    2|
# | flume|    1|
# | sqoop|    3|
# |hadoop|    1|
# |  hive|    2|
# +------+-----+
# -------------------------------------------
# Batch: 13
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# | kafka|    1|
# |apache|    2|
# | spark|    2|
# | flume|    1|
# | sqoop|    3|
# |hadoop|    1|
# |  hive|    3|
# +------+-----+
# -------------------------------------------
# Batch: 14
# -------------------------------------------
# +------+-----+
# |  word|count|
# +------+-----+
# | kafka|    1|
# |apache|    2|
# | spark|    2|
# | flume|    1|
# | sqoop|    3|
# |hadoop|    1|
# |  hive|    4|
# +------+-----+
